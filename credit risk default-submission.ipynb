# %% [markdown]
# # Home Credit Default Risk Competition

# %%
import pandas as pd

import gc
import re
import joblib

# %% [markdown]
# ## Load Data

# %%
#Test Dataset
X_test = pd.read_csv('/kaggle/input/home-loan/test_output_final_model.csv')
print(X_test.shape)
X_test.head()
# Out:
# (48744, 505)
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          135000.0    568800.0      20560.5         450000.0
# 1             0           99000.0    222768.0      17370.0         180000.0
# 2             0          202500.0    663264.0      69777.0         630000.0
# 3             2          315000.0   1575000.0      49018.5        1575000.0
# 4             1          180000.0    625500.0      32067.0         625500.0
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0.01884      -19241          -2329            -5168.0
# 1                     0.03580      -18064          -4469            -9120.0
# 2                     0.01910      -20038          -4458            -2176.0
# 3                     0.02640      -13976          -1866            -2000.0
# 4                     0.01003      -13040          -2191            -4000.0
#
# ...

# %% [markdown]
# ## Preprocessing/ Feature Engineering

# %%
print(len(X_test))
X_test.head()
# Out:
# 48744
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          135000.0    568800.0      20560.5         450000.0
# 1             0           99000.0    222768.0      17370.0         180000.0
# 2             0          202500.0    663264.0      69777.0         630000.0
# 3             2          315000.0   1575000.0      49018.5        1575000.0
# 4             1          180000.0    625500.0      32067.0         625500.0
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0.01884      -19241          -2329            -5168.0
# 1                     0.03580      -18064          -4469            -9120.0
# 2                     0.01910      -20038          -4458            -2176.0
# 3                     0.02640      -13976          -1866            -2000.0
# 4                     0.01003      -13040          -2191            -4000.0
#
# ...

# %% [markdown]
# ## Load Model

# %%
model = joblib.load('/kaggle/input/home-loan/hcd_model_week_8.joblib')
print(type(model))
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# ...

# %% [markdown]
# ## Test Predictions

# %%
test_pred = model.predict_proba(X_test)
print(test_pred.shape)
# Out:
# (48744, 2)

# %%
submission = pd.read_csv('../input/home-credit-default-risk/sample_submission.csv')
submission.head()
# Out:
#    SK_ID_CURR  TARGET
# 0      100001     0.5
# 1      100005     0.5
# 2      100013     0.5
# 3      100028     0.5
# 4      100038     0.5

# %%
submission.TARGET = [item[1] for item in test_pred]
submission.head()
# Out:
#    SK_ID_CURR    TARGET
# 0      100001  0.012539
# 1      100005  0.083988
# 2      100013  0.012525
# 3      100028  0.029952
# 4      100038  0.077930

# %%
submission.to_csv('submission.csv', index=False, header=True)
